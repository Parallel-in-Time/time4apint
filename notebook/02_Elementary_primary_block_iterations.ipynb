# %%
from blockops import BlockOperator, BlockIteration, one, PintRun

# %%
nBlocks = 4

phi = BlockOperator(r'$\phi$')  # fine operator
phiDInv = BlockOperator(r'$\phi_{\Delta}^{-1}$')  # coarse operator
chi = BlockOperator(r'$\chi$')  # transmission operator

blockOps = dict(i=one, phi=phi, phiDInv=phiDInv, chi=chi)

# %%
block_jacobi = BlockIteration(
    "phiDInv*chi*u_{n}^k + (i-phiDInv*phi)* u_{n+1}^{k}",
    "i * u_{n}^0",
    **blockOps)

# %%
PintRun(block_jacobi, nBlocks)

# %%
block_jacobi = BlockIteration(
    "phiDInv*chi*u_{n}^k + (i-phiDInv*phi)* u_{n+1}^{k}",
    "phiDInv*chi * u_{n}^0",
    **blockOps)
PintRun(block_jacobi, nBlocks)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_9672/3346604575.py in <cell line: 5>()
#       3     "phiDInv*chi * u_{n}^0",
#       4     **blockOps)
# ----> 5 PintRun(block_jacobi, nBlocks)
#
# ~/Recherche/codes/time4apint/notebook/blockops/run.py in __init__(self, blockIteration, nBlocks)
#      28                                                             cost=0)
#      29
# ---> 30         self.createExpressions()
#      31         self.pintGraph.generateGraphFromPool(pool=self.taskPool)
#      32         self.pintGraph.plotGraph()
#
# ~/Recherche/codes/time4apint/notebook/blockops/run.py in createExpressions(self)
#     155                     rule = self.substitute_and_simplify(self.createIterationRule(n=n + 1, k=k + 1))
#     156                     res = self.createSymbolForUnk(n=n + 1, k=k + 1)
# --> 157                     self.taskGenerator(rule=rule, res=res)
#     158                     if len(rule.args) > 0:
#     159                         self.computation_to_approx[rule] = res
#
# ~/Recherche/codes/time4apint/notebook/blockops/run.py in taskGenerator(self, rule, res)
#     102                 if isinstance(expr, sy.Add) or isinstance(expr, sy.Mul):
#     103                     self.tasks[expr] = key
# --> 104                     self.taskPool[key] = Task(op=expr, result=key, cost=0)
#     105                 else:
#     106                     self.localsave[key] = expr
#
# ~/Recherche/codes/time4apint/notebook/blockops/run.py in __init__(self, op, result, cost)
#     209         # TODO: Find a better way to set the name
#     210         if len(op.args) > 0:
# --> 211             if len(re.split('u_|u\^', op.args[0].name)) > 1:
#     212                 self.name = result
#     213             else:
#
# AttributeError: 'Integer' object has no attribute 'name'

# %%
i = BlockOperator(r'I')  # transmission operator

blockOps2 = dict(i=i, phi=phi, phiDInv=phiDInv, chi=chi)

# %%
block_jacobi = BlockIteration(
    "phiDInv*chi*u_{n}^k + (i-phiDInv*phi)* u_{n+1}^{k}",
    "i * u_{n}^0",
    **blockOps2)

PintRun(block_jacobi, nBlocks)

# %%
block_jacobi = BlockIteration(
    "phiDInv*chi*u_{n}^k + (i-phiDInv*phi)* u_{n+1}^{k}",
    "i * u_{n}^0",
    rules=[('i', '1')],
    **blockOps2)

PintRun(block_jacobi, nBlocks)
